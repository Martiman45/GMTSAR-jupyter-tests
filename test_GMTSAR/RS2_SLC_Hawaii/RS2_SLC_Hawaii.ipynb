# %% [markdown]
# February 14, 2014
# Revised january 20, 2016
# Revised January 29, 2019
# Adapted to Jupyter September 5, 2023
#
#  This is an example set of RADARSAT-2 SLC images for an example interferogram.  The region is in Hawaii and is centered on the Kilauea Caldera. The data are part of the Hawaii Supersite.
#
#  The file configure.rs2.txt contains reasonable processing parammeters.  Note the /topo directory already contains a file dem.grd that is needed for removal of the topographic phase.  There is a  web site http://topex.ucsd.edu/gmtsar that will generate a dem.grd file for a selected area based on the best available data (SRTM or ASTER).
#
#
#
# ### Use these instructions if you are using the GMTSAR trunk:
#
# Trunk users may use the instructions for v5.6 or the following instructions employing a generic p2p code.
# The advantages of the generic p2p code is that it automatically generates the SLCs and other necessary files and generates a default config file if none is given, making it more user friendly.
#
#
#
# 1. This code requires the raw data files to be in the same directory.
# Of course, this is not ideal for keeping different data sets organized, but we may fulfill both tasks by linking the requisite files into the raw directory.

# %%
import os
os.chdir("raw")
# !ln -s RS2_OK43873_PK423873_DK374693_FQ16_20110515_161531_HH_VV_HV_VH_SLC/product.xml ./RS220110515.xml
# !ln -s RS2_OK43873_PK423873_DK374693_FQ16_20110515_161531_HH_VV_HV_VH_SLC/imagery_HH.tif ./RS220110515.tif
# !ln -s RS2_OK43874_PK423902_DK375296_FQ16_20110819_161534_HH_VV_HV_VH_SLC/product.xml ./RS220110819.xml
# !ln -s RS2_OK43874_PK423902_DK375296_FQ16_20110819_161534_HH_VV_HV_VH_SLC/imagery_HH.tif ./RS220110819.tif
# Out:
# ln: ./RS220110515.xml: File exists
# ln: ./RS220110515.tif: File exists
# ln: ./RS220110819.xml: File exists
# ln: ./RS220110819.tif: File exists

# %% [markdown]
# 2. Now we may create the interferogram by running the the p2p code:

# %%
os.chdir("..")
# !pop_config.csh RS2 > config.txt
# !p2p_processing.csh RS2 RS220110515 RS220110819 config.txt
# Out:
# PREPROCESS - START
#
# Working on images RS220110515 RS220110819 ...
# rm: No match.
# rm: No match.
# pre_proc.csh RS2 RS220110515 RS220110819  -skip_master 0
# pre_proc.csh
#
#
#  Pre-Process CSK/TSX/RS2/S1_STRIP/GF3 SLC data - START
#
# 2633 1620
# 1
# PRM set for Image File...
# 5 Lines Written for Orbit...
# Writing SLC..Image Size: 3416 X 5749...
# Fliping leftside right for Descending Image...
# 2633 1620
# 1
# PRM set for Image File...
# 5 Lines Written for Orbit...
# Writing SLC..Image Size: 3416 X 5746...
# Fliping leftside right for Descending Image...
# Successfully opened RS220110515.PRM0
# Successfully opened RS220110819.PRM0
#
#  Pre-Process SLC data - END
#
#
# PREPROCESS - END
#
# rm: No match.
# rm: No match.
#
# ALIGN.CSH - START
#
# using command line
# ......master LED file RS220110515.LED
# .........aligned LED file RS220110819.LED
#  setting xsearch to 128
#  setting nx_corr to 256
#  setting ysearch to 128
#  setting ny_corr to 256
#  setting nx to 20
#  setting ny to 50
#  3416 5744 3416 5744 8 2 0.000000
#  locations  n 1000 nx 3416 nyl 50 nxl 20 x_inc 115 y_inc 97
#  elapsed time: 115.407770
#
# ALIGN.CSH - END
#
#
# clean up topo/ folder
#
#
# DEM2TOPO_RA.CSH - START
# USER SHOULD PROVIDE DEM FILE
# Working over 0/3416/0/5744 ...
#  range decimation is:  2
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: Cartesian input grid
# blockmedian [INFORMATION]: Cartesian input grid
# blockmedian [INFORMATION]: W: 0 E: 3416 S: 0 N: 5744 n_columns: 1708 n_rows: 1436
# blockmedian [INFORMATION]: Input 3 columns via binary records using format ddd
# blockmedian [INFORMATION]: Output 3 columns via binary records using format ddd
# blockmedian [INFORMATION]: Reading Data Table from Standard Input stream
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 978883 N used: 966534 outside_area: 12349 N cells filled: 964812
# surface [INFORMATION]: Provides 3, expects 3-column binary data
# surface [INFORMATION]: Enable all available threads (up to 8)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Internally speed up convergence by using the larger region -R-21/3435/-10/5750 (go from 1708 x 1436 to optimal 1728 x 1440, with speedup-factor 10.785653)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Grid domain: W: 0 E: 3416 S: 0 N: 5744 n_columns: 1728 n_rows: 1440 [pixel registration]
# surface [INFORMATION]: Processing input table data
# surface [INFORMATION]: Input 3 columns via binary records using format ddd
# surface [INFORMATION]: Reading Data Table from file temp.rat
# surface [INFORMATION]: Minimum value of your dataset x,y,z at: 451.370147705 4836 -168.468673706
# surface [INFORMATION]: Maximum value of your dataset x,y,z at: 3394.09008789 172 2847.90234375
# surface [INFORMATION]: Eliminate data points that are not nearest a node.
# surface [WARNING]: 920 unusable points were supplied; these will be ignored.
# surface [WARNING]: You should have pre-processed the data with block-mean, -median, or -mode.
# surface [WARNING]: Check that previous processing steps write results with enough decimals.
# surface [WARNING]: Possibly some data were half-way between nodes and subject to IEEE 754 rounding.
# surface [INFORMATION]: Plane fit z = 1092.16 + (0.725536 * col) + (-1.07554 * row)
# surface [INFORMATION]: Normalize detrended data constraints by z rms = 204.24
# surface [INFORMATION]: Select default convergence limit of 0.020424 (100 ppm of L2 scale)
# surface [INFORMATION]: Recompute data index for next iteration [stride = 288]
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Memory for data array          :   22.1 Mb
# surface [INFORMATION]: Memory for final grid          :    9.6 Mb
# surface [INFORMATION]: Memory for Briggs coefficients :   22.1 Mb
# surface [INFORMATION]: Memory for node status         :    2.4 Mb
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Total memory use               :   56.1 Mb
# surface [INFORMATION]: ==========================================
# surface [INFORMATION]: Grid	Mode	Iteration	Max Change	Conv Limit	Total Iterations
# surface [INFORMATION]: Set finite-difference coefficients [stride = 288]
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 288]
# surface [INFORMATION]:  288	D	       1	-204.240350865	7.0916788495e-05	         1
# surface [INFORMATION]: Recompute data index for next iteration [stride = 96]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 288 to 96
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 96]
# surface [INFORMATION]:   96	I	      52	0.000180018197818	0.000212750365485	        53
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 96]
# surface [INFORMATION]:   96	D	      14	0.000106530235407	0.000212750365485	        67
# surface [INFORMATION]: Recompute data index for next iteration [stride = 32]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 96 to 32
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 32]
# surface [INFORMATION]:   32	I	      49	0.000546306833302	0.000638251096455	       116
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 32]
# surface [INFORMATION]:   32	D	      16	0.000288301259516	0.000638251096455	       132
# surface [INFORMATION]: Recompute data index for next iteration [stride = 16]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 32 to 16
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 16]
# surface [INFORMATION]:   16	I	      28	0.00117236446071	0.00127650219291	       160
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 16]
# surface [INFORMATION]:   16	D	      28	0.000995912355679	0.00127650219291	       188
# surface [INFORMATION]: Recompute data index for next iteration [stride = 8]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 16 to 8
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 8]
# surface [INFORMATION]:    8	I	      28	0.00200432919082	0.00255300438582	       216
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 8]
# surface [INFORMATION]:    8	D	      35	0.00240123064532	0.00255300438582	       251
# surface [INFORMATION]: Recompute data index for next iteration [stride = 4]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 8 to 4
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 4]
# surface [INFORMATION]:    4	I	      24	0.00504291780849	0.00510600877164	       275
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 4]
# surface [INFORMATION]:    4	D	     261	0.0050844112622	0.00510600877164	       536
# surface [INFORMATION]: Recompute data index for next iteration [stride = 2]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 4 to 2
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 2]
# surface [INFORMATION]:    2	I	      18	0.0101864272112	0.0102120175433	       554
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 2]
# surface [INFORMATION]:    2	D	     452	0.0102103246616	0.0102120175433	      1006
# surface [INFORMATION]: Recompute data index for next iteration [stride = 1]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 2 to 1
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 1]
# surface [INFORMATION]:    1	I	      15	0.0178006365922	0.0204240350865	      1021
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 1]
# surface [INFORMATION]:    1	D	     156	0.0204231039064	0.0204240350865	      1177
# surface [INFORMATION]: Compute rms misfit and curvature.
# surface [INFORMATION]: Fit info: N data points  N nodes	mean error	rms error	curvature
# surface [INFORMATION]: 	  963892	 2491489	3.30225236885e-05	0.00399923619735	2776.27812858
# surface [INFORMATION]: Increase pad by 10 10 2 2
# surface [INFORMATION]: Writing grid to file pixel.grd
# grd2cpt [INFORMATION]: Reading CPT from File /Users/martinhawks/miniconda3/envs/Insar/share/gmt/cpt/gmt/gray.cpt
# grd2cpt [INFORMATION]: Processing input grid(s)
# grd2cpt [INFORMATION]: netCDF grid topo_ra.grd has no default CPT.
# grd2cpt [INFORMATION]: Cartesian input grid
# grd2cpt [INFORMATION]: Reading grid from file topo_ra.grd
# grd2cpt [INFORMATION]: Cartesian input grid
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grd2cpt [INFORMATION]: Mean and S.D. of data are 942.687610632 602.5460859
# grd2cpt [INFORMATION]: z = -173.424804688 and CDF(z) = 0
# grd2cpt [INFORMATION]: z = 170.493730935 and CDF(z) = 0.101338246584
# grd2cpt [INFORMATION]: z = 435.572030533 and CDF(z) = 0.148020517905
# grd2cpt [INFORMATION]: z = 626.712134256 and CDF(z) = 0.253292001792
# grd2cpt [INFORMATION]: z = 790.034305264 and CDF(z) = 0.401169411344
# grd2cpt [INFORMATION]: z = 942.687610632 and CDF(z) = 0.584814531981
# grd2cpt [INFORMATION]: z = 1095.340916 and CDF(z) = 0.693138178659
# grd2cpt [INFORMATION]: z = 1258.66308701 and CDF(z) = 0.766075328813
# grd2cpt [INFORMATION]: z = 1449.80319073 and CDF(z) = 0.833732147641
# grd2cpt [INFORMATION]: z = 1714.88149033 and CDF(z) = 0.885998906505
# grd2cpt [INFORMATION]: z = 2848.15087891 and CDF(z) = 1
# grd2cpt [INFORMATION]: Write CPT to Stream Standard output stream
# grdimage [INFORMATION]: GMT_Parse_Options: Interval-setting -B options were reordered to appear before axis and frame -B options to ensure proper parsing.
# grdimage [INFORMATION]: GMT_Parse_Options: New option order: topo_ra.grd -JX7i -P -Ctopo_ra.cpt -V -K -Bxaf+lRange -B"yaf+lReversed Azimuth" -BWSen
# grdimage [INFORMATION]: Read header from file topo_ra.grd
# grdimage [INFORMATION]: netCDF grid topo_ra.grd has no default CPT.
# grdimage [INFORMATION]: Cartesian input grid
# grdimage [INFORMATION]: Linear projection implies x-axis distance exaggeration relative to the y-axis by a factor of 0.594708
# grdimage [INFORMATION]: Auto-frame interval for x-axis (item 0): a500f100
# grdimage [INFORMATION]: Auto-frame interval for y-axis (item 0): a1000f200
# grdimage [INFORMATION]: Map scale is 0.192126 km per cm or 1:19212.6.
# grdimage [INFORMATION]: Allocate and read data from file topo_ra.grd
# grdimage [INFORMATION]: Reading grid from file topo_ra.grd
# grdimage [INFORMATION]: Cartesian input grid
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: topo_ra.cpt
# grdimage [INFORMATION]: Reading CPT from File topo_ra.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> gray image with no illumination.
# grdimage [INFORMATION]: Plotting 8-bit grayshade image
# PSL: DEFLATE compressed 2452688 to 321197 bytes (86.9% savings at compression level 5)
# Topo range/azimuth map: topo_ra.pdf
# DEM2TOPO_RA.CSH - END
# NO TOPO_RA SHIFT
#
# INTF.CSH, FILTER.CSH - START
# using command line
# ......master LED file RS220110515.LED
# .........aligned LED file RS220110819.LED
# using command line
# ......master LED file RS220110515.LED
# .........aligned LED file RS220110515.LED
# intf.csh
# running phasediff...
# reading topo topo_ra.grd
#  xdim 3416, ydim 5744
# filter.csh
# gauss_100 1 1 (4 2)
# making amplitudes...
# filtering interferogram...
# making amplitude...
# making correlation...
# making phase...
# filtering phase...
# INTF.CSH, FILTER.CSH - END
#
# SKIP UNWRAP PHASE
#
# GEOCODE.CSH - START
# threshold_geocode: .10
# grdmath [INFORMATION]: Enable all available threads (up to 8)
# grdmath [INFORMATION]: Perform reverse Polish notation calculations on grids
# grdmath [INFORMATION]: netCDF grid corr.grd has no default CPT.
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: corr.grd grdmath [INFORMATION]: netCDF grid corr.grd has no default CPT.
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: Reading grid from file corr.grd
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# 0.1 GE 0 NAN mask.grd grdmath [INFORMATION]: netCDF grid mask.grd has no default CPT.
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: Reading grid from file mask.grd
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# MUL = mask2.grdgrdmath [INFORMATION]: Writing grid to file mask2.grd
#
# Masked phase map: phase_mask.pdf
# Filtered masked phase map: phasefilt_mask.pdf
# geocode.csh
# project correlation, phase, unwrapped and amplitude back to lon lat coordinates
# remarked is by martinhawks on Thu Sep 7 12:02:11 PDT 2023 with geocode.csh
# proj_ra2ll.csh
# surface [INFORMATION]: Provides 5, expects 3-column binary data
# surface [INFORMATION]: Enable all available threads (up to 8)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Internally speed up convergence by using the larger region -R-16/3440/0/5760 (go from 214 x 180 to optimal 216 x 180, with speedup-factor 10.499147)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Grid domain: W: 0 E: 3424 S: 0 N: 5760 n_columns: 216 n_rows: 180 [gridline registration]
# surface [INFORMATION]: Processing input table data
# surface [INFORMATION]: Input 5 columns via binary records using format ddddd
# surface [INFORMATION]: Reading Data Table from file trans.dat
# surface [INFORMATION]: Minimum value of your dataset x,y,z at: 3425.65087891 5340 -155.492492676
# surface [INFORMATION]: Maximum value of your dataset x,y,z at: -9.26521682739 -14.0000009537 -155.180557251
# surface [INFORMATION]: Eliminate data points that are not nearest a node.
# surface [WARNING]: 939098 unusable points were supplied; these will be ignored.
# surface [WARNING]: You should have pre-processed the data with block-mean, -median, or -mode.
# surface [WARNING]: Check that previous processing steps write results with enough decimals.
# surface [WARNING]: Possibly some data were half-way between nodes and subject to IEEE 754 rounding.
# surface [INFORMATION]: Plane fit z = -155.187 + (-0.00126766 * col) + (-0.000194399 * row)
# surface [INFORMATION]: Normalize detrended data constraints by z rms = 0.00238639
# surface [INFORMATION]: Select default convergence limit of 2.38639e-07 (100 ppm of L2 scale)
# surface [INFORMATION]: Recompute data index for next iteration [stride = 36]
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Memory for data array          :  916.2 kb
# surface [INFORMATION]: Memory for final grid          :  159.7 kb
# surface [INFORMATION]: Memory for Briggs coefficients :  916.2 kb
# surface [INFORMATION]: Memory for node status         :   39.9 kb
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Total memory use               :    2.0 Mb
# surface [INFORMATION]: ==========================================
# surface [INFORMATION]: Grid	Mode	Iteration	Max Change	Conv Limit	Total Iterations
# surface [INFORMATION]: Set finite-difference coefficients [stride = 36]
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 36]
# surface [INFORMATION]:   36	D	       1	-0.00238639384619	6.62887179497e-09	         1
# surface [INFORMATION]: Recompute data index for next iteration [stride = 12]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 36 to 12
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 12]
# surface [INFORMATION]:   12	I	      32	1.8906272809e-08	1.98866153849e-08	        33
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 12]
# surface [INFORMATION]:   12	D	      13	1.41547505246e-08	1.98866153849e-08	        46
# surface [INFORMATION]: Recompute data index for next iteration [stride = 4]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 12 to 4
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 4]
# surface [INFORMATION]:    4	I	      30	4.48471363236e-08	5.96598461547e-08	        76
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 4]
# surface [INFORMATION]:    4	D	      13	2.70678588747e-08	5.96598461547e-08	        89
# surface [INFORMATION]: Recompute data index for next iteration [stride = 2]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 4 to 2
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 2]
# surface [INFORMATION]:    2	I	      20	8.84460411825e-08	1.19319692309e-07	       109
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 2]
# surface [INFORMATION]:    2	D	      13	9.06813792312e-08	1.19319692309e-07	       122
# surface [INFORMATION]: Recompute data index for next iteration [stride = 1]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 2 to 1
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 1]
# surface [INFORMATION]:    1	I	      17	2.19647251205e-07	2.38639384619e-07	       139
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 1]
# surface [INFORMATION]:    1	D	      13	1.66158296805e-07	2.38639384619e-07	       152
# surface [INFORMATION]: Compute rms misfit and curvature.
# surface [INFORMATION]: Fit info: N data points  N nodes	mean error	rms error	curvature
# surface [INFORMATION]: 	   39092	   39277	3.22600814813e-06	0.00366129557129	1630.71499831
# surface [INFORMATION]: Increase pad by 1 1 0 0
# surface [INFORMATION]: Writing grid to file raln.grd
# surface [INFORMATION]: Provides 5, expects 3-column binary data
# surface [INFORMATION]: Enable all available threads (up to 8)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Internally speed up convergence by using the larger region -R-16/3440/0/5760 (go from 214 x 180 to optimal 216 x 180, with speedup-factor 10.499147)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Grid domain: W: 0 E: 3424 S: 0 N: 5760 n_columns: 216 n_rows: 180 [gridline registration]
# surface [INFORMATION]: Processing input table data
# surface [INFORMATION]: Input 5 columns via binary records using format ddddd
# surface [INFORMATION]: Reading Data Table from file trans.dat
# surface [INFORMATION]: Minimum value of your dataset x,y,z at: 1.4709533453 5764 19.2194442749
# surface [INFORMATION]: Maximum value of your dataset x,y,z at: 3422.79418945 -10.0000019073 19.5386104584
# surface [INFORMATION]: Eliminate data points that are not nearest a node.
# surface [WARNING]: 939098 unusable points were supplied; these will be ignored.
# surface [WARNING]: You should have pre-processed the data with block-mean, -median, or -mode.
# surface [WARNING]: Check that previous processing steps write results with enough decimals.
# surface [WARNING]: Possibly some data were half-way between nodes and subject to IEEE 754 rounding.
# surface [INFORMATION]: Plane fit z = 19.486 + (0.000239105 * col) + (-0.00148325 * row)
# surface [INFORMATION]: Normalize detrended data constraints by z rms = 0.00043712
# surface [INFORMATION]: Select default convergence limit of 4.3712e-08 (100 ppm of L2 scale)
# surface [INFORMATION]: Recompute data index for next iteration [stride = 36]
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Memory for data array          :  916.2 kb
# surface [INFORMATION]: Memory for final grid          :  159.7 kb
# surface [INFORMATION]: Memory for Briggs coefficients :  916.2 kb
# surface [INFORMATION]: Memory for node status         :   39.9 kb
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Total memory use               :    2.0 Mb
# surface [INFORMATION]: ==========================================
# surface [INFORMATION]: Grid	Mode	Iteration	Max Change	Conv Limit	Total Iterations
# surface [INFORMATION]: Set finite-difference coefficients [stride = 36]
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 36]
# surface [INFORMATION]:   36	D	       1	-0.00043711977681	1.21422160225e-09	         1
# surface [INFORMATION]: Recompute data index for next iteration [stride = 12]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 36 to 12
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 12]
# surface [INFORMATION]:   12	I	      32	3.26784209454e-09	3.64266480675e-09	        33
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 12]
# surface [INFORMATION]:   12	D	      13	3.54853498213e-09	3.64266480675e-09	        46
# surface [INFORMATION]: Recompute data index for next iteration [stride = 4]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 12 to 4
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 4]
# surface [INFORMATION]:    4	I	      32	8.20788616068e-09	1.09279944202e-08	        78
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 4]
# surface [INFORMATION]:    4	D	      13	7.73670711107e-09	1.09279944202e-08	        91
# surface [INFORMATION]: Recompute data index for next iteration [stride = 2]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 4 to 2
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 2]
# surface [INFORMATION]:    2	I	      20	1.67299988678e-08	2.18559888405e-08	       111
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 2]
# surface [INFORMATION]:    2	D	      14	2.07183024217e-08	2.18559888405e-08	       125
# surface [INFORMATION]: Recompute data index for next iteration [stride = 1]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 2 to 1
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 1]
# surface [INFORMATION]:    1	I	      18	3.40352564918e-08	4.3711977681e-08	       143
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 1]
# surface [INFORMATION]:    1	D	      15	3.26658822799e-08	4.3711977681e-08	       158
# surface [INFORMATION]: Compute rms misfit and curvature.
# surface [INFORMATION]: Fit info: N data points  N nodes	mean error	rms error	curvature
# surface [INFORMATION]: 	   39092	   39277	-0.000155442926048	0.0123044187352	3515.01733913
# surface [INFORMATION]: Increase pad by 1 1 0 0
# surface [INFORMATION]: Writing grid to file ralt.grd
# Sampling in geocoordinates with 25 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 204.508333333 E: 204.819444444 S: 19.2194444444 N: 19.5388888889 n_columns: 1120 n_rows: 1150
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 2452688 N used: 2452688 outside_area: 0 N cells filled: 966519
# proj_ra2ll.csh
# Sampling in geocoordinates with 25 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 204.508333333 E: 204.819444444 S: 19.2194444444 N: 19.5388888889 n_columns: 1120 n_rows: 1150
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 2452688 N used: 2452688 outside_area: 0 N cells filled: 966519
# proj_ra2ll.csh
# Sampling in geocoordinates with 25 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 204.508333333 E: 204.819444444 S: 19.2194444444 N: 19.5388888889 n_columns: 1120 n_rows: 1150
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 2103184 N used: 2103184 outside_area: 0 N cells filled: 872430
# proj_ra2ll.csh
# Sampling in geocoordinates with 25 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 204.508333333 E: 204.819444444 S: 19.2194444444 N: 19.5388888889 n_columns: 1120 n_rows: 1150
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 2452688 N used: 2452688 outside_area: 0 N cells filled: 966519
# proj_ra2ll.csh
# Sampling in geocoordinates with 25 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 204.508333333 E: 204.819444444 S: 19.2194444444 N: 19.5388888889 n_columns: 1120 n_rows: 1150
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 2103184 N used: 2103184 outside_area: 0 N cells filled: 872430
# geocode.csh
# make the KML files for Google Earth
# grdimage [INFORMATION]: Read header from file display_amp_ll.grd
# grdimage [INFORMATION]: netCDF grid display_amp_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for longitude from 0.000277777777678569864 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for latitude from 0.000277777777826088146 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmin from 204.5083333333333 to 204.5083333333333
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmax from 204.8194444444445 to 204.8194444444445
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 19.21944444444444 to 19.21944444444444
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 19.53888888888889 to 19.53888888888889
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file display_amp_ll.grd
# grdimage [INFORMATION]: Reading grid from file display_amp_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: display_amp.cpt
# grdimage [INFORMATION]: Reading CPT from File display_amp.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Colormap of 256 colors created
# PSL: DEFLATE compressed 1288000 to 793424 bytes (38.4% savings at compression level 5)
# Make display_amp_ll.kml and display_amp_ll.png
# psconvert [INFORMATION]: Processing display_amp_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 22.38 points [0.310833 inch]  Height: 22.98 points [0.319166 inch]
# psconvert [INFORMATION]: [144 144 166.38 166.98]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1119x1149 -r3600 -sOutputFile='display_amp_ll.png' './psconvert_92814d.eps'
# psconvert [INFORMATION]: Wrote KML file display_amp_ll.kml
# grdimage [INFORMATION]: Read header from file corr_ll.grd
# grdimage [INFORMATION]: netCDF grid corr_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for longitude from 0.000277777777678569864 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for latitude from 0.000277777777826088146 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmin from 204.5083333333333 to 204.5083333333333
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmax from 204.8194444444445 to 204.8194444444445
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 19.21944444444444 to 19.21944444444444
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 19.53888888888889 to 19.53888888888889
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file corr_ll.grd
# grdimage [INFORMATION]: Reading grid from file corr_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: corr.cpt
# grdimage [INFORMATION]: Reading CPT from File corr.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Colormap of 255 colors created
# PSL: DEFLATE compressed 1288000 to 869977 bytes (32.5% savings at compression level 5)
# Make corr_ll.kml and corr_ll.png
# psconvert [INFORMATION]: Processing corr_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 22.38 points [0.310833 inch]  Height: 22.98 points [0.319166 inch]
# psconvert [INFORMATION]: [144 144 166.38 166.98]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1119x1149 -r3600 -sOutputFile='corr_ll.png' './psconvert_92829d.eps'
# psconvert [INFORMATION]: Wrote KML file corr_ll.kml
# grdimage [INFORMATION]: Read header from file phase_mask_ll.grd
# grdimage [INFORMATION]: netCDF grid phase_mask_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for longitude from 0.000277777777678569864 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for latitude from 0.000277777777826088146 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmin from 204.5083333333333 to 204.5083333333333
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmax from 204.8194444444445 to 204.8194444444445
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 19.21944444444444 to 19.21944444444444
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 19.53888888888889 to 19.53888888888889
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file phase_mask_ll.grd
# grdimage [INFORMATION]: Reading grid from file phase_mask_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: phase.cpt
# grdimage [INFORMATION]: Reading CPT from File phase.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 3864000 to 1448944 bytes (62.5% savings at compression level 5)
# Make phase_mask_ll.kml and phase_mask_ll.png
# psconvert [INFORMATION]: Processing phase_mask_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 22.38 points [0.310833 inch]  Height: 22.98 points [0.319166 inch]
# psconvert [INFORMATION]: [144 144 166.38 166.98]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1119x1149 -r3600 -sOutputFile='phase_mask_ll.png' './psconvert_92844d.eps'
# psconvert [INFORMATION]: Wrote KML file phase_mask_ll.kml
# grdimage [INFORMATION]: Read header from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: netCDF grid phasefilt_mask_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for longitude from 0.000277777777678569864 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for latitude from 0.000277777777826088146 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmin from 204.5083333333333 to 204.5083333333333
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmax from 204.8194444444445 to 204.8194444444445
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 19.21944444444444 to 19.21944444444444
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 19.53888888888889 to 19.53888888888889
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: Reading grid from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: phase.cpt
# grdimage [INFORMATION]: Reading CPT from File phase.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 3864000 to 1335247 bytes (65.4% savings at compression level 5)
# Make phasefilt_mask_ll.kml and phasefilt_mask_ll.png
# psconvert [INFORMATION]: Processing phasefilt_mask_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 22.38 points [0.310833 inch]  Height: 22.98 points [0.319166 inch]
# psconvert [INFORMATION]: [144 144 166.38 166.98]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1119x1149 -r3600 -sOutputFile='phasefilt_mask_ll.png' './psconvert_92863d.eps'
# psconvert [INFORMATION]: Wrote KML file phasefilt_mask_ll.kml
# grdimage [INFORMATION]: Read header from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: netCDF grid phasefilt_mask_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for longitude from 0.000277777777678569864 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed geographic grid increment for latitude from 0.000277777777826088146 to 0.000277777777777777778
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmin from 204.5083333333333 to 204.5083333333333
# grdimage [INFORMATION]: Round-off patrol changed grid limit for xmax from 204.8194444444445 to 204.8194444444445
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 19.21944444444444 to 19.21944444444444
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 19.53888888888889 to 19.53888888888889
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: Reading grid from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: phase.cpt
# grdimage [INFORMATION]: Reading CPT from File phase.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 3864000 to 1335247 bytes (65.4% savings at compression level 5)
# Make phasefilt_mask_ll.kml and phasefilt_mask_ll.png
# psconvert [INFORMATION]: Processing phasefilt_mask_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 22.38 points [0.310833 inch]  Height: 22.98 points [0.319166 inch]
# psconvert [INFORMATION]: [144 144 166.38 166.98]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1119x1149 -r3600 -sOutputFile='phasefilt_mask_ll.png' './psconvert_92883d.eps'
# psconvert [INFORMATION]: Wrote KML file phasefilt_mask_ll.kml
# GEOCODE.CSH - END
