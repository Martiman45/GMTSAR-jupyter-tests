# %% [markdown]
# November 20, 2013
# David T. Sandwell
# Adapted to Jupyter on September 5, 2023
#
# This is an example set of ALOS PALSAR data to make an interferogram of T213, F0660 starting with L1.1 (SLC) images. The raw data consist of a L1.1 (SLC) FBS image a L1.1 FBD image. The file configure.txt contains reasonable processing parameters.
#
# The /raw directory should contain 4 files.
# ```
# IMG-HH-ALPSRP223500660-H1.1__A
# LED-ALPSRP223500660-H1.1__A
# IMG-HH-ALPSRP230210660-H1.1__A
# LED-ALPSRP230210660-H1.1__A
# ```
#
# These are the names provided by JAXA AUIG and it is important to have this name format.  If you have ERSDAC data, the simplest approach is to rename the files using this format.  The number 207600640 must simply have the correct number of digits and the IMG and LED numbers should match for each scene.
#
# Note we have not tested any of this code for mixing L1.1 and L1.0 data.  Also this code will not work with L1.1 data from ERSDAC.
#
# Note the /topo directory already contains a file dem.grd that is needed for removal of the topographic phase.  There is a  web site http://topex.ucsd.edu/gmtsar that will generate a dem.grd file for a selected area based on the best available data (SRTM or ASTER).
#
# #### Command for GMTSAR

# %%
# !pop_config.csh ALOS_SLC > config.txt
# !p2p_processing.csh ALOS_SLC IMG-HH-ALPSRP223500660-H1.1__A IMG-HH-ALPSRP230210660-H1.1__A config.txt
# Out:
# PREPROCESS - START
#
# Working on images IMG-HH-ALPSRP223500660-H1.1__A IMG-HH-ALPSRP230210660-H1.1__A ...
# rm: No match.
# rm: No match.
# pre_proc.csh ALOS_SLC IMG-HH-ALPSRP223500660-H1.1__A IMG-HH-ALPSRP230210660-H1.1__A  -SLC_factor 0.02 -skip_master 0
# pre_proc.csh
# -SLC_factor 0.02
#
#  Pre-Process ALOS SLC data - START
#
#  setting SLC_factor to 0.020000
#  processing ALOS1 L1.1
# .... swapping bytes
# writing generic LED file: IMG-HH-ALPSRP223500660-H1.1__A.LED
#  38545 integers were clipped
#  setting SLC_factor to 0.020000
#  processing ALOS1 L1.1
# .... swapping bytes
# writing generic LED file: IMG-HH-ALPSRP230210660-H1.1__A.LED
#  12865 integers were clipped
# Convert the aligned image from FBD to FBS mode
# Overwriting the old aligned image
#
#  Pre-Process ALOS SLC data - END
#
#
# PREPROCESS - END
#
# rm: No match.
# rm: No match.
#
# ALIGN.CSH - START
#
# using command line
# ......master LED file IMG-HH-ALPSRP223500660-H1.1__A.LED
# .........aligned LED file IMG-HH-ALPSRP230210660-H1.1__A.LED
#  setting xsearch to 128
#  setting nx_corr to 256
#  setting ysearch to 128
#  setting ny_corr to 256
#  setting nx to 20
#  setting ny to 50
#  9344 18432 9344 18432 0 14 0.000000
#  locations  n 1000 nx 9344 nyl 50 nxl 20 x_inc 372 y_inc 346
#  elapsed time: 111.395293
#
# ALIGN.CSH - END
#
#
# clean up topo/ folder
#
#
# DEM2TOPO_RA.CSH - START
# USER SHOULD PROVIDE DEM FILE
# Working over 0/9344/0/18432 ...
#  range decimation is:  2
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: Cartesian input grid
# blockmedian [INFORMATION]: Cartesian input grid
# blockmedian [INFORMATION]: W: 0 E: 9344 S: 0 N: 18432 n_columns: 4672 n_rows: 4608
# blockmedian [INFORMATION]: Input 3 columns via binary records using format ddd
# blockmedian [INFORMATION]: Output 3 columns via binary records using format ddd
# blockmedian [INFORMATION]: Reading Data Table from Standard Input stream
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 5036665 N used: 5016274 outside_area: 20391 N cells filled: 4969338
# surface [INFORMATION]: Provides 3, expects 3-column binary data
# surface [INFORMATION]: Enable all available threads (up to 8)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cannot suggest any n_columns,n_rows better than your current -R -I settings.
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Grid domain: W: 0 E: 9344 S: 0 N: 18432 n_columns: 4672 n_rows: 4608 [pixel registration]
# surface [INFORMATION]: Processing input table data
# surface [INFORMATION]: Input 3 columns via binary records using format ddd
# surface [INFORMATION]: Reading Data Table from file temp.rat
# surface [INFORMATION]: Minimum value of your dataset x,y,z at: 8513.15527344 2869.65161133 -394.525939941
# surface [INFORMATION]: Maximum value of your dataset x,y,z at: 1280.8236084 15221.9707031 2893.94311523
# surface [INFORMATION]: Eliminate data points that are not nearest a node.
# surface [INFORMATION]: Plane fit z = 1264.4 + (-0.305047 * col) + (-0.0364046 * row)
# surface [INFORMATION]: Normalize detrended data constraints by z rms = 521.841
# surface [INFORMATION]: Select default convergence limit of 0.0521841 (100 ppm of L2 scale)
# surface [INFORMATION]: Recompute data index for next iteration [stride = 64]
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Memory for data array          :  113.7 Mb
# surface [INFORMATION]: Memory for final grid          :   82.3 Mb
# surface [INFORMATION]: Memory for Briggs coefficients :  113.7 Mb
# surface [INFORMATION]: Memory for node status         :   20.6 Mb
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Total memory use               :  330.4 Mb
# surface [INFORMATION]: ==========================================
# surface [INFORMATION]: Grid	Mode	Iteration	Max Change	Conv Limit	Total Iterations
# surface [INFORMATION]: Set finite-difference coefficients [stride = 64]
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 64]
# surface [INFORMATION]:   64	D	     542	0.000796012562995	0.000815376516604	       542
# surface [INFORMATION]: Recompute data index for next iteration [stride = 32]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 64 to 32
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 32]
# surface [INFORMATION]:   32	I	      31	0.00147203750392	0.00163075303321	       573
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 32]
# surface [INFORMATION]:   32	D	    1245	0.00163036436666	0.00163075303321	      1818
# surface [INFORMATION]: Recompute data index for next iteration [stride = 16]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 32 to 16
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 16]
# surface [INFORMATION]:   16	I	      29	0.00318736352018	0.00326150606641	      1847
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 16]
# surface [INFORMATION]:   16	D	    1870	0.00325978208529	0.00326150606641	      3717
# surface [INFORMATION]: Recompute data index for next iteration [stride = 8]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 16 to 8
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 8]
# surface [INFORMATION]:    8	I	      26	0.005608888879	0.00652301213283	      3743
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 8]
# surface [INFORMATION]:    8	D	     760	0.00649802793086	0.00652301213283	      4503
# surface [INFORMATION]: Recompute data index for next iteration [stride = 4]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 8 to 4
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 4]
# surface [INFORMATION]:    4	I	      23	0.010364374666	0.0130460242657	      4526
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 4]
# surface [INFORMATION]:    4	D	    1833	0.0130360517358	0.0130460242657	      6359
# surface [INFORMATION]: Recompute data index for next iteration [stride = 2]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 4 to 2
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 2]
# surface [INFORMATION]:    2	I	      18	0.0209800843517	0.0260920485313	      6377
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 2]
# surface [INFORMATION]:    2	D	      74	0.0260512772172	0.0260920485313	      6451
# surface [INFORMATION]: Recompute data index for next iteration [stride = 1]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 2 to 1
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 1]
# surface [INFORMATION]:    1	I	      15	0.0369938170954	0.0521840970626	      6466
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 1]
# surface [INFORMATION]:    1	D	      87	0.0513423961612	0.0521840970626	      6553
# surface [INFORMATION]: Compute rms misfit and curvature.
# surface [INFORMATION]: Fit info: N data points  N nodes	mean error	rms error	curvature
# surface [INFORMATION]: 	 4969338	21537857	-6.25358724864e-07	0.00205130016615	15945.7547118
# surface [INFORMATION]: Writing grid to file pixel.grd
# grd2cpt [INFORMATION]: Reading CPT from File /Users/martinhawks/miniconda3/envs/Insar/share/gmt/cpt/gmt/gray.cpt
# grd2cpt [INFORMATION]: Processing input grid(s)
# grd2cpt [INFORMATION]: netCDF grid topo_ra.grd has no default CPT.
# grd2cpt [INFORMATION]: Cartesian input grid
# grd2cpt [INFORMATION]: Reading grid from file topo_ra.grd
# grd2cpt [INFORMATION]: Cartesian input grid
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grd2cpt [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grd2cpt [INFORMATION]: Mean and S.D. of data are 467.385981024 668.741551993
# grd2cpt [INFORMATION]: z = -394.626617432 and CDF(z) = 0
# grd2cpt [INFORMATION]: z = -389.640801877 and CDF(z) = 1.20769721173e-06
# grd2cpt [INFORMATION]: z = -95.4411089059 and CDF(z) = 0.323038659084
# grd2cpt [INFORMATION]: z = 116.69756829 and CDF(z) = 0.409501046864
# grd2cpt [INFORMATION]: z = 297.96224608 and CDF(z) = 0.45705231303
# grd2cpt [INFORMATION]: z = 467.385981024 and CDF(z) = 0.500286619063
# grd2cpt [INFORMATION]: z = 636.809715968 and CDF(z) = 0.548886630908
# grd2cpt [INFORMATION]: z = 818.074393758 and CDF(z) = 0.617504177587
# grd2cpt [INFORMATION]: z = 1030.21307095 and CDF(z) = 0.766538147555
# grd2cpt [INFORMATION]: z = 1324.41276393 and CDF(z) = 0.908064653606
# grd2cpt [INFORMATION]: z = 2894.39648438 and CDF(z) = 1
# grd2cpt [INFORMATION]: Write CPT to Stream Standard output stream
# grdimage [INFORMATION]: GMT_Parse_Options: Interval-setting -B options were reordered to appear before axis and frame -B options to ensure proper parsing.
# grdimage [INFORMATION]: GMT_Parse_Options: New option order: topo_ra.grd -JX7i -P -Ctopo_ra.cpt -V -K -Bxaf+lRange -B"yaf+lReversed Azimuth" -BWSen
# grdimage [INFORMATION]: Read header from file topo_ra.grd
# grdimage [INFORMATION]: netCDF grid topo_ra.grd has no default CPT.
# grdimage [INFORMATION]: Cartesian input grid
# grdimage [INFORMATION]: Linear projection implies x-axis distance exaggeration relative to the y-axis by a factor of 0.506944
# grdimage [INFORMATION]: Auto-frame interval for x-axis (item 0): a2000f1000
# grdimage [INFORMATION]: Auto-frame interval for y-axis (item 0): a5000f1000
# grdimage [INFORMATION]: Map scale is 0.525534 km per cm or 1:52553.4.
# grdimage [INFORMATION]: Allocate and read data from file topo_ra.grd
# grdimage [INFORMATION]: Reading grid from file topo_ra.grd
# grdimage [INFORMATION]: Cartesian input grid
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: topo_ra.cpt
# grdimage [INFORMATION]: Reading CPT from File topo_ra.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> gray image with no illumination.
# grdimage [INFORMATION]: Plotting 8-bit grayshade image
# PSL: DEFLATE compressed 21528576 to 3238938 bytes (85.0% savings at compression level 5)
# Topo range/azimuth map: topo_ra.pdf
# DEM2TOPO_RA.CSH - END
#
# OFFSET_TOPO - START
#  range decimation is: 2
#  4608 4608 4608
#  optimal: rshift = 0  ashift = 0  max_correlation = 0.380870
# OFFSET_TOPO - END
#
# INTF.CSH, FILTER.CSH - START
# using command line
# ......master LED file IMG-HH-ALPSRP223500660-H1.1__A.LED
# .........aligned LED file IMG-HH-ALPSRP230210660-H1.1__A.LED
# using command line
# ......master LED file IMG-HH-ALPSRP223500660-H1.1__A.LED
# .........aligned LED file IMG-HH-ALPSRP223500660-H1.1__A.LED
# intf.csh
# running phasediff...
# reading topo topo_shift.grd
#  xdim 9344, ydim 18432
# filter.csh
# gauss_200 2 2 (4 2)
# making amplitudes...
# filtering interferogram...
# making amplitude...
# making correlation...
# making phase...
# filtering phase...
# INTF.CSH, FILTER.CSH - END
#
# SKIP UNWRAP PHASE
#
# GEOCODE.CSH - START
# threshold_geocode: .10
# grdmath [INFORMATION]: Enable all available threads (up to 8)
# grdmath [INFORMATION]: Perform reverse Polish notation calculations on grids
# grdmath [INFORMATION]: netCDF grid corr.grd has no default CPT.
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: corr.grd grdmath [INFORMATION]: netCDF grid corr.grd has no default CPT.
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: Reading grid from file corr.grd
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# 0.1 GE 0 NAN mask.grd grdmath [INFORMATION]: netCDF grid mask.grd has no default CPT.
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: Reading grid from file mask.grd
# grdmath [INFORMATION]: Cartesian input grid
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdmath [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# MUL = mask2.grdgrdmath [INFORMATION]: Writing grid to file mask2.grd
#
# Masked phase map: phase_mask.pdf
# Filtered masked phase map: phasefilt_mask.pdf
# geocode.csh
# project correlation, phase, unwrapped and amplitude back to lon lat coordinates
# remarked is by martinhawks on Wed Sep 6 16:44:06 PDT 2023 with geocode.csh
# proj_ra2ll.csh
# surface [INFORMATION]: Provides 5, expects 3-column binary data
# surface [INFORMATION]: Enable all available threads (up to 8)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Internally speed up convergence by using the larger region -R-128/9472/0/18432 (go from 584 x 576 to optimal 600 x 576, with speedup-factor 1.3498465)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Grid domain: W: 0 E: 9344 S: 0 N: 18432 n_columns: 600 n_rows: 576 [gridline registration]
# surface [INFORMATION]: Processing input table data
# surface [INFORMATION]: Input 5 columns via binary records using format ddddd
# surface [INFORMATION]: Reading Data Table from file trans.dat
# surface [INFORMATION]: Minimum value of your dataset x,y,z at: -6.43320274353 18444.1640625 -116.833885193
# surface [INFORMATION]: Maximum value of your dataset x,y,z at: 9353.10351562 6528.22070312 -116.029998779
# surface [INFORMATION]: Eliminate data points that are not nearest a node.
# surface [WARNING]: 4698614 unusable points were supplied; these will be ignored.
# surface [WARNING]: You should have pre-processed the data with block-mean, -median, or -mode.
# surface [WARNING]: Check that previous processing steps write results with enough decimals.
# surface [WARNING]: Possibly some data were half-way between nodes and subject to IEEE 754 rounding.
# surface [INFORMATION]: Plane fit z = -116.722 + (0.00123921 * col) + (-0.000192711 * row)
# surface [INFORMATION]: Normalize detrended data constraints by z rms = 0.00686828
# surface [INFORMATION]: Select default convergence limit of 6.86828e-07 (100 ppm of L2 scale)
# surface [INFORMATION]: Recompute data index for next iteration [stride = 24]
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Memory for data array          :    7.7 Mb
# surface [INFORMATION]: Memory for final grid          :    1.3 Mb
# surface [INFORMATION]: Memory for Briggs coefficients :    7.7 Mb
# surface [INFORMATION]: Memory for node status         :  343.3 kb
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Total memory use               :   17.1 Mb
# surface [INFORMATION]: ==========================================
# surface [INFORMATION]: Grid	Mode	Iteration	Max Change	Conv Limit	Total Iterations
# surface [INFORMATION]: Set finite-difference coefficients [stride = 24]
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 24]
# surface [INFORMATION]:   24	D	      30	2.507460328e-08	2.86178255318e-08	        30
# surface [INFORMATION]: Recompute data index for next iteration [stride = 8]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 24 to 8
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 8]
# surface [INFORMATION]:    8	I	      36	7.56058990344e-08	8.58534765953e-08	        66
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 8]
# surface [INFORMATION]:    8	D	     144	8.4823800803e-08	8.58534765953e-08	       210
# surface [INFORMATION]: Recompute data index for next iteration [stride = 4]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 8 to 4
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 4]
# surface [INFORMATION]:    4	I	      24	1.21599885614e-07	1.71706953191e-07	       234
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 4]
# surface [INFORMATION]:    4	D	     263	1.70937152634e-07	1.71706953191e-07	       497
# surface [INFORMATION]: Recompute data index for next iteration [stride = 2]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 4 to 2
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 2]
# surface [INFORMATION]:    2	I	      19	3.36071325655e-07	3.43413906381e-07	       516
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 2]
# surface [INFORMATION]:    2	D	     257	3.41408634067e-07	3.43413906381e-07	       773
# surface [INFORMATION]: Recompute data index for next iteration [stride = 1]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 2 to 1
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 1]
# surface [INFORMATION]:    1	I	      15	5.343994973e-07	6.86827812762e-07	       788
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 1]
# surface [INFORMATION]:    1	D	     238	6.80859061019e-07	6.86827812762e-07	      1026
# surface [INFORMATION]: Compute rms misfit and curvature.
# surface [INFORMATION]: Fit info: N data points  N nodes	mean error	rms error	curvature
# surface [INFORMATION]: 	  335907	  346777	1.34945093479e-06	0.00259978800864	10342.7205849
# surface [INFORMATION]: Increase pad by 8 8 0 0
# surface [INFORMATION]: Writing grid to file raln.grd
# surface [INFORMATION]: Provides 5, expects 3-column binary data
# surface [INFORMATION]: Enable all available threads (up to 8)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Internally speed up convergence by using the larger region -R-128/9472/0/18432 (go from 584 x 576 to optimal 600 x 576, with speedup-factor 1.3498465)
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Cartesian input grid
# surface [INFORMATION]: Grid domain: W: 0 E: 9344 S: 0 N: 18432 n_columns: 600 n_rows: 576 [gridline registration]
# surface [INFORMATION]: Processing input table data
# surface [INFORMATION]: Input 5 columns via binary records using format ddddd
# surface [INFORMATION]: Reading Data Table from file trans.dat
# surface [INFORMATION]: Minimum value of your dataset x,y,z at: -9.63720989227 -13.8308048248 33.369720459
# surface [INFORMATION]: Maximum value of your dataset x,y,z at: 9338.16894531 18446.2460938 33.9955558777
# surface [INFORMATION]: Eliminate data points that are not nearest a node.
# surface [WARNING]: 4698614 unusable points were supplied; these will be ignored.
# surface [WARNING]: You should have pre-processed the data with block-mean, -median, or -mode.
# surface [WARNING]: Check that previous processing steps write results with enough decimals.
# surface [WARNING]: Possibly some data were half-way between nodes and subject to IEEE 754 rounding.
# surface [INFORMATION]: Plane fit z = 33.3705 + (0.000185412 * col) + (0.000892124 * row)
# surface [INFORMATION]: Normalize detrended data constraints by z rms = 0.00102621
# surface [INFORMATION]: Select default convergence limit of 1.02621e-07 (100 ppm of L2 scale)
# surface [INFORMATION]: Recompute data index for next iteration [stride = 24]
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Memory for data array          :    7.7 Mb
# surface [INFORMATION]: Memory for final grid          :    1.3 Mb
# surface [INFORMATION]: Memory for Briggs coefficients :    7.7 Mb
# surface [INFORMATION]: Memory for node status         :  343.3 kb
# surface [INFORMATION]: ------------------------------------------
# surface [INFORMATION]: Total memory use               :   17.1 Mb
# surface [INFORMATION]: ==========================================
# surface [INFORMATION]: Grid	Mode	Iteration	Max Change	Conv Limit	Total Iterations
# surface [INFORMATION]: Set finite-difference coefficients [stride = 24]
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 24]
# surface [INFORMATION]:   24	D	      30	4.25315609111e-09	4.27589396096e-09	        30
# surface [INFORMATION]: Recompute data index for next iteration [stride = 8]
# surface [INFORMATION]: Expand grid by factor of 3 when going from stride = 24 to 8
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 8]
# surface [INFORMATION]:    8	I	      36	1.21029408228e-08	1.28276818829e-08	        66
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 8]
# surface [INFORMATION]:    8	D	     136	1.2738059769e-08	1.28276818829e-08	       202
# surface [INFORMATION]: Recompute data index for next iteration [stride = 4]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 8 to 4
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 4]
# surface [INFORMATION]:    4	I	      24	1.85968536461e-08	2.56553637658e-08	       226
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 4]
# surface [INFORMATION]:    4	D	     249	2.55189365455e-08	2.56553637658e-08	       475
# surface [INFORMATION]: Recompute data index for next iteration [stride = 2]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 4 to 2
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 2]
# surface [INFORMATION]:    2	I	      20	3.47709782776e-08	5.13107275315e-08	       495
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 2]
# surface [INFORMATION]:    2	D	     412	5.12448219622e-08	5.13107275315e-08	       907
# surface [INFORMATION]: Recompute data index for next iteration [stride = 1]
# surface [INFORMATION]: Expand grid by factor of 2 when going from stride = 2 to 1
# surface [INFORMATION]: Fill in expanded grid by bilinear interpolation [stride = 1]
# surface [INFORMATION]:    1	I	      15	7.5258027073e-08	1.02621455063e-07	       922
# surface [INFORMATION]: Determine nearest point and set Briggs coefficients [stride = 1]
# surface [INFORMATION]:    1	D	     261	1.02189924872e-07	1.02621455063e-07	      1183
# surface [INFORMATION]: Compute rms misfit and curvature.
# surface [INFORMATION]: Fit info: N data points  N nodes	mean error	rms error	curvature
# surface [INFORMATION]: 	  335907	  346777	2.33703878057e-06	0.00455151482641	11564.571471
# surface [INFORMATION]: Increase pad by 8 8 0 0
# surface [INFORMATION]: Writing grid to file ralt.grd
# Sampling in geocoordinates with 50 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 243.166666667 E: 244.005555556 S: 33.3666666667 N: 33.9958333333 n_columns: 1510 n_rows: 1510
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 5356800 N used: 5356800 outside_area: 0 N cells filled: 1672645
# proj_ra2ll.csh
# Sampling in geocoordinates with 50 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 243.166666667 E: 244.005555556 S: 33.3666666667 N: 33.9958333333 n_columns: 1510 n_rows: 1510
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 5361408 N used: 5361408 outside_area: 0 N cells filled: 1674028
# proj_ra2ll.csh
# Sampling in geocoordinates with 50 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 243.166666667 E: 244.005555556 S: 33.3666666667 N: 33.9958333333 n_columns: 1510 n_rows: 1510
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 5174287 N used: 5174287 outside_area: 0 N cells filled: 1624452
# proj_ra2ll.csh
# Sampling in geocoordinates with 50 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 243.166666667 E: 244.005555556 S: 33.3666666667 N: 33.9958333333 n_columns: 1510 n_rows: 1510
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 5382144 N used: 5382144 outside_area: 0 N cells filled: 1679697
# proj_ra2ll.csh
# Sampling in geocoordinates with 50 meter pixels ...
# blockmedian [INFORMATION]: Provides 3, expects 3-column binary data
# blockmedian [INFORMATION]: Processing input table data
# blockmedian [INFORMATION]: W: 243.166666667 E: 244.005555556 S: 33.3666666667 N: 33.9958333333 n_columns: 1510 n_rows: 1510
# blockmedian [INFORMATION]: Input 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Output 3 columns via binary records using format fff
# blockmedian [INFORMATION]: Reading Data Table from file llp
# blockmedian [INFORMATION]: Writing Data Table to Standard Output stream
# blockmedian [INFORMATION]: Calculating block medians
# blockmedian [INFORMATION]: N read: 5174287 N used: 5174287 outside_area: 0 N cells filled: 1624452
# geocode.csh
# make the KML files for Google Earth
# grdimage [INFORMATION]: Read header from file display_amp_ll.grd
# grdimage [INFORMATION]: netCDF grid display_amp_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 33.36666666313106 to 33.36666666313106
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 33.99583332973105 to 33.99583332973105
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file display_amp_ll.grd
# grdimage [INFORMATION]: Reading grid from file display_amp_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: display_amp.cpt
# grdimage [INFORMATION]: Reading CPT from File display_amp.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 6840300 to 2255141 bytes (67.0% savings at compression level 5)
# Make display_amp_ll.kml and display_amp_ll.png
# psconvert [INFORMATION]: Processing display_amp_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 60.426 points [0.83925 inch]  Height: 45.3 points [0.629166 inch]
# psconvert [INFORMATION]: [144 144 204.426 189.3]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1511x1133 -r1800 -sOutputFile='display_amp_ll.png' './psconvert_73343d.eps'
# psconvert [INFORMATION]: Wrote KML file display_amp_ll.kml
# grdimage [INFORMATION]: Read header from file corr_ll.grd
# grdimage [INFORMATION]: netCDF grid corr_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 33.36666666313106 to 33.36666666313106
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 33.99583332973105 to 33.99583332973105
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file corr_ll.grd
# grdimage [INFORMATION]: Reading grid from file corr_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: corr.cpt
# grdimage [INFORMATION]: Reading CPT from File corr.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Colormap of 223 colors created
# PSL: DEFLATE compressed 2280100 to 1512344 bytes (33.7% savings at compression level 5)
# Make corr_ll.kml and corr_ll.png
# psconvert [INFORMATION]: Processing corr_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 60.426 points [0.83925 inch]  Height: 45.3 points [0.629166 inch]
# psconvert [INFORMATION]: [144 144 204.426 189.3]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1511x1133 -r1800 -sOutputFile='corr_ll.png' './psconvert_73360d.eps'
# psconvert [INFORMATION]: Wrote KML file corr_ll.kml
# grdimage [INFORMATION]: Read header from file phase_mask_ll.grd
# grdimage [INFORMATION]: netCDF grid phase_mask_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 33.36666666313106 to 33.36666666313106
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 33.99583332973105 to 33.99583332973105
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file phase_mask_ll.grd
# grdimage [INFORMATION]: Reading grid from file phase_mask_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: phase.cpt
# grdimage [INFORMATION]: Reading CPT from File phase.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 6840300 to 2310878 bytes (66.2% savings at compression level 5)
# Make phase_mask_ll.kml and phase_mask_ll.png
# psconvert [INFORMATION]: Processing phase_mask_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 60.426 points [0.83925 inch]  Height: 45.3 points [0.629166 inch]
# psconvert [INFORMATION]: [144 144 204.426 189.3]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1511x1133 -r1800 -sOutputFile='phase_mask_ll.png' './psconvert_73376d.eps'
# psconvert [INFORMATION]: Wrote KML file phase_mask_ll.kml
# grdimage [INFORMATION]: Read header from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: netCDF grid phasefilt_mask_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 33.36666666313106 to 33.36666666313106
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 33.99583332973105 to 33.99583332973105
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: Reading grid from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: phase.cpt
# grdimage [INFORMATION]: Reading CPT from File phase.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 6840300 to 2012902 bytes (70.6% savings at compression level 5)
# Make phasefilt_mask_ll.kml and phasefilt_mask_ll.png
# psconvert [INFORMATION]: Processing phasefilt_mask_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 60.426 points [0.83925 inch]  Height: 45.3 points [0.629166 inch]
# psconvert [INFORMATION]: [144 144 204.426 189.3]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1511x1133 -r1800 -sOutputFile='phasefilt_mask_ll.png' './psconvert_73394d.eps'
# psconvert [INFORMATION]: Wrote KML file phasefilt_mask_ll.kml
# grdimage [INFORMATION]: Read header from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: netCDF grid phasefilt_mask_ll.grd has no default CPT.
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymin from 33.36666666313106 to 33.36666666313106
# grdimage [INFORMATION]: Round-off patrol changed grid limit for ymax from 33.99583332973105 to 33.99583332973105
# grdimage [INFORMATION]: Map scale is 0.001 km per inch or 1:39.3701.
# grdimage [INFORMATION]: Allocate and read data from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: Reading grid from file phasefilt_mask_ll.grd
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for all edges: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for left   edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for right  edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for bottom edge: natural
# grdimage [INFORMATION]: gmt_grd_BC_set: Set boundary condition for top    edge: natural
# grdimage [INFORMATION]: gmt_cpt_default: Use specific CPT: phase.cpt
# grdimage [INFORMATION]: Reading CPT from File phase.cpt
# grdimage [INFORMATION]: Evaluate image pixel colors
# grdimage [INFORMATION]: Basic z(x,y) -> color image with no illumination.
# grdimage [INFORMATION]: Plotting 24-bit color image
# PSL: Too many colors to make colormap - using 24-bit direct color instead.
# PSL: DEFLATE compressed 6840300 to 2012902 bytes (70.6% savings at compression level 5)
# Make phasefilt_mask_ll.kml and phasefilt_mask_ll.png
# psconvert [INFORMATION]: Processing phasefilt_mask_ll.ps...
# psconvert [INFORMATION]: Find HiResBoundingBox ...
# psconvert [INFORMATION]: Figure dimensions: Width: 60.426 points [0.83925 inch]  Height: 45.3 points [0.629166 inch]
# psconvert [INFORMATION]: [144 144 204.426 189.3]...
# psconvert [INFORMATION]: Convert to PNG...
# gs -q -dNOPAUSE -dBATCH -dNOSAFER -dSCANCONVERTERTYPE=2 -dMaxBitmap=2147483647 -dUseFastColor=true -dGraphicsAlphaBits=2 -dTextAlphaBits=4 -sDEVICE=pngalpha  -g1511x1133 -r1800 -sOutputFile='phasefilt_mask_ll.png' './psconvert_73416d.eps'
# psconvert [INFORMATION]: Wrote KML file phasefilt_mask_ll.kml
# GEOCODE.CSH - END

# %% [markdown]
# The resulting corr_ll should look like this:
#
# ![cor_ll](images/ALOS_SLC_L1.1.png)
